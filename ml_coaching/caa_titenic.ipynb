# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"D:\py_machine_learning\datasets\titanic - titanic.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean()<25 and df[var].isnull().mean()>0]
cols
# Out:
# ['Age', 'Fare', 'Cabin']

# %%
df[cols].sample(5)
# Out:
#       Age     Fare Cabin
# 110  41.0  15.0458   NaN
# 336  32.0  13.0000   NaN
# 178  36.0  39.0000    F4
# 204  25.0  10.5000   NaN
# 259  21.0   7.7750   NaN

# %%
df['Age'].value_counts()
# Out:
# Age
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 44.0     1
# 5.0      1
# 51.0     1
# 3.0      1
# 38.5     1
# Name: count, Length: 79, dtype: int64

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.20813397129186603

# %%
new_df = df[cols].dropna()
df.shape , new_df.shape
# Out:
# ((418, 12), (87, 3))

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# orignal data 
df['Age'].hist(bins=50,ax=ax ,density=True,color='red')

# data after cca , the argument alpha makes the color transparent so we can see the overlap of the 2 distribution 

new_df['Age'].hist(bins=50,ax=ax ,density=True,color='green', alpha=0.8)
# Out:
# <Axes: >

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(86)

# %%
new_df.dropna()
# Out:
#       Age      Fare            Cabin
# 12   23.0   82.2667              B45
# 14   47.0   61.1750              E31
# 24   48.0  262.3750  B57 B59 B63 B66
# 26   22.0   61.9792              B36
# 28   41.0   30.5000              A21
# ..    ...       ...              ...
# 404  43.0   27.7208              D40
# 405  20.0   13.8625              D38
# 407  50.0  211.5000              C80
# 411  37.0   90.0000              C78
# 414  39.0  108.9000             C105
#
# [87 rows x 3 columns]

# %%
new_df.isnull().sum()
# Out:
# Age      0
# Fare     0
# Cabin    0
# dtype: int64
