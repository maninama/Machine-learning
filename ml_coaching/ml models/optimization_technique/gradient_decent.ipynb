# %%
# optimization technique ---> it is used from minimize the error of prediction and actual value.

# (1). Gradient Descent ::::

# Loss function = y_act = y_pred

# %%
# we know the equation of simple line :::
# y = mx + b ......... (1) where (x,y) ----> cordinates , m --> slope , b ---> intercept

# y_pred = mx+b
# y_act = mx+b

# so we will calculate loss function w.r.t mean squared error :::
