# %%
import pandas as pd 
import numpy as np

# %%
pd.set_option("display.max_rows",500)

# %%
dataset = pd.read_csv(r"D:\py_machine_learning\datasets\groceries - groceries.csv")
dataset.head()
# Out:
#              Item 1               Item 2          Item 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9 Item 10  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN     NaN
# 1                       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 2                       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN     NaN
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN     NaN
#
#   Item 11 Item 12
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
dataset.shape
# Out:
# (9835, 12)

# %%
market = []
for i in range(0,dataset.shape[0]):
 cus = []
 for j in dataset.columns :
   if type(dataset[j][i])==str:
     cus.append(dataset[j][i])
 market.append(cus)

# %%
l = []
for i in market:
    for j in i :
        l.append(j)

# %%
l
# Out:
# ['citrus fruit',
#  'semi-finished bread',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'yogurt',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'beef',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetable juice',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'sausage',
#  'rolls/buns',
#  'soda',
#  'chocolate',
#  'other vegetables',
#  'brown bread',
#  'soda',
#  'fruit/vegetable juice',
#  'canned beer',
#  'newspapers',
#  'shopping bags',
#  'yogurt',
#  'beverages',
#  'bottled water',
#  'specialty bar',
#  'hamburger meat',
#  'other vegetables',
#  'rolls/buns',
#  'spices',
#  'bottled water',
#  'hygiene articles',
#  'napkins',
#  'root vegetables',
#  'other vegetables',
#  'whole milk',
#  'beverages',
#  'sugar',
#  'pork',
#  'berries',
#  'other vegetables',
#  'whole milk',
#  'whipped/sour cream',
#  'artif. sweetener',
#  'soda',
#  'abrasive cleaner',
#  'beef',
#  'grapes',
#  'detergent',
#  'pastry',
#  'soda',
#  'fruit/vegetable juice',
#  'canned beer',
#  'root vegetables',
#  'other vegetables',
#  'whole milk',
#  'dessert',
#  'citrus fruit',
#  'zwieback',
#  'newspapers',
#  'sausage',
#  'rolls/buns',
#  'soda',
#  'canned beer',
#  'specialty bar',
#  'shopping bags',
#  'tropical fruit',
#  'root vegetables',
#  'whole milk',
#  'yogurt',
#  'domestic eggs',
#  'brown bread',
#  'pastry',
#  'sugar',
#  'cereals',
#  'coffee',
#  'soda',
#  'waffles',
#  'berries',
#  'yogurt',
#  'canned beer',
#  'butter milk',
#  'yogurt',
#  'cream cheese',
#  'spread cheese',
#  'rolls/buns',
#  'bottled water',
#  'soda',
#  'newspapers',
#  'coffee',
#  'pastry',
#  'bottled water',
#  'rolls/buns',
#  'misc. beverages',
#  'root vegetables',
#  'other vegetables',
#  'butter',
#  'curd',
#  'whipped/sour cream',
#  'UHT-milk',
#  'hard cheese',
#  'rolls/buns',
#  'bottled water',
#  'long life bakery product',
#  'sausage',
#  'rolls/buns',
#  'cat food',
#  'newspapers',
#  'canned beer',
#  'ham',
#  'grapes',
#  'other vegetables',
#  'whole milk',
#  'turkey',
#  'tropical fruit',
#  'other vegetables',
#  'curd',
#  'domestic eggs',
#  'brown bread',
#  'semi-finished bread',
#  'margarine',
#  'baking powder',
#  'fruit/vegetable juice',
#  'whole milk',
#  'yogurt',
#  'processed cheese',
#  'pickled vegetables',
#  'soda',
#  'whole milk',
#  'curd',
#  'yogurt',
#  'pastry',
#  'packaged fruit/vegetables',
#  'brown bread',
#  'canned beer',
#  'rolls/buns',
#  'oil',
#  'bottled water',
#  'chewing gum',
#  'chocolate marshmallow',
#  'hygiene articles',
#  'napkins',
#  'ham',
#  'beef',
#  'whipped/sour cream',
#  'ice cream',
#  'rolls/buns',
#  'cat food',
#  'rolls/buns',
#  'pastry',
#  'sugar',
#  'other vegetables',
#  'whole milk',
#  'frozen vegetables',
#  'canned fish',
#  'salty snack',
#  'seasonal products',
#  'detergent',
#  'sausage',
#  'pastry',
#  'sausage',
#  'beef',
#  'whole milk',
#  'frankfurter',
#  'tropical fruit',
#  'rolls/buns',
#  'brown bread',
#  'sugar',
#  'rolls/buns',
#  'pastry',
#  'soda',
#  'whole milk',
#  'curd cheese',
#  'coffee',
#  'red/blush wine',
#  'newspapers',
#  'sausage',
#  'whole milk',
#  'curd',
#  'tropical fruit',
#  'pip fruit',
#  'berries',
#  'whole milk',
#  'frozen potato products',
#  'rolls/buns',
#  'pickled vegetables',
#  'chocolate',
#  'red/blush wine',
#  'whole milk',
#  'butter',
#  'margarine',
#  'specialty fat',
#  'specialty chocolate',
#  'candles',
#  'flower (seeds)',
#  'frankfurter',
#  'citrus fruit',
#  'whole milk',
#  'domestic eggs',
#  'oil',
#  'sparkling wine',
#  'specialty chocolate',
#  'newspapers',
#  'whole milk',
#  'meat spreads',
#  'soda',
#  'frozen potato products',
#  'other vegetables',
#  'whole milk',
#  'rolls/buns',
#  'sugar',
#  'citrus fruit',
#  'whole milk',
#  'curd',
#  'butter milk',
#  'pastry',
#  'flour',
#  'salt',
#  'bottled water',
#  'fruit/vegetable juice',
#  'bottled beer',
#  'sugar',
#  'bottled water',
#  'soda',
#  'bottled beer',
#  'frozen meals',
#  'coffee',
#  'chocolate',
#  'root vegetables',
#  'whole milk',
#  'frozen vegetables',
#  'domestic eggs',
#  'rolls/buns',
#  'oil',
#  'margarine',
#  'canned vegetables',
#  'fruit/vegetable juice',
#  'bathroom cleaner',
#  'root vegetables',
#  'onions',
#  'hard cheese',
#  'frozen vegetables',
#  'herbs',
#  'condensed milk',
#  'frozen vegetables',
#  'salt',
#  'oil',
#  'white wine',
#  'candles',
#  'bottled water',
#  'sausage',
#  'root vegetables',
#  'onions',
#  'yogurt',
#  'rolls/buns',
#  'brandy',
#  'detergent',
#  'coffee',
#  'newspapers',
#  'pork',
#  'other vegetables',
#  'whipped/sour cream',
#  'berries',
#  'yogurt',
#  'soda',
#  'berries',
#  'fruit/vegetable juice',
#  'salty snack',
#  'candles',
#  'citrus fruit',
#  'butter milk',
#  'yogurt',
#  'cream cheese',
#  'pork',
#  'hamburger meat',
#  'citrus fruit',
#  'berries',
#  'onions',
#  'whipped/sour cream',
#  'rice',
#  'coffee',
#  'chocolate',
#  'detergent',
#  'grapes',
#  'photo/film',
#  'sausage',
#  'sliced cheese',
#  'rolls/buns',
#  'brown bread',
#  'fruit/vegetable juice',
#  'canned beer',
#  'red/blush wine',
#  'waffles',
#  'shopping bags',
#  'chicken',
#  'hamburger meat',
#  'citrus fruit',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'butter',
#  'pasta',
#  'oil',
#  'detergent',
#  'whole milk',
#  'yogurt',
#  'brown bread',
#  'citrus fruit',
#  'tropical fruit',
#  'soda',
#  'misc. beverages',
#  'sausage',
#  'pork',
#  'grapes',
#  'whole milk',
#  'rolls/buns',
#  'pastry',
#  'soda',
#  'specialty bar',
#  'bathroom cleaner',
#  'frankfurter',
#  'rolls/buns',
#  'bottled water',
#  'sausage',
#  'whole milk',
#  'yogurt',
#  'coffee',
#  'fruit/vegetable juice',
#  'bottled beer',
#  'softener',
#  'napkins',
#  'photo/film',
#  'shopping bags',
#  'soda',
#  'rolls/buns',
#  'fruit/vegetable juice',
#  'beef',
#  'citrus fruit',
#  'berries',
#  'root vegetables',
#  'brown bread',
#  'detergent',
#  'whole milk',
#  'whipped/sour cream',
#  'rolls/buns',
#  'soda',
#  'waffles',
#  'candy',
#  'cling film/bags',
#  'processed cheese',
#  'tropical fruit',
#  'pip fruit',
#  'frankfurter',
#  'sausage',
#  'root vegetables',
#  'other vegetables',
#  'rolls/buns',
#  'oil',
#  'pickled vegetables',
#  'bottled beer',
#  'chewing gum',
#  'dishes',
#  'packaged fruit/vegetables',
#  'bottled water',
#  'whole milk',
#  'dessert',
#  'frozen vegetables',
#  'rolls/buns',
#  'margarine',
#  'bottled water',
#  'red/blush wine',
#  'newspapers',
#  'berries',
#  'whipped/sour cream',
#  'citrus fruit',
#  'berries',
#  'UHT-milk',
#  'processed cheese',
#  'tropical fruit',
#  'whole milk',
#  'yogurt',
#  'hamburger meat',
#  'whole milk',
#  'frozen vegetables',
#  'rolls/buns',
#  'bottled beer',
#  'sparkling wine',
#  'hamburger meat',
#  'other vegetables',
#  'whole milk',
#  'frozen vegetables',
#  'domestic eggs',
#  'soda',
#  'dishes',
#  'whole milk',
#  'cream cheese',
#  'soda',
#  'fish',
#  'other vegetables',
#  'pastry',
#  'margarine',
#  'coffee',
#  'long life bakery product',
#  'male cosmetics',
#  'shopping bags',
#  'frankfurter',
#  'sausage',
#  'long life bakery product',
#  'waffles',
#  'packaged fruit/vegetables',
#  'dessert',
#  'semi-finished bread',
#  'canned beer',
#  'pastry',
#  'soda',
#  'other vegetables',
#  'red/blush wine',
#  'misc. beverages',
#  'frankfurter',
#  'sausage',
#  'citrus fruit',
#  'tropical fruit',
#  'pip fruit',
#  'whole milk',
#  'hard cheese',
#  'cream cheese',
#  'domestic eggs',
#  'rice',
#  'sugar',
#  'canned fruit',
#  'sparkling wine',
#  'specialty bar',
#  'sausage',
#  'butter milk',
#  'rolls/buns',
#  'curd cheese',
#  'frankfurter',
#  'dessert',
#  'whole milk',
#  'yogurt',
#  'beverages',
#  'brown bread',
#  'shopping bags',
#  'newspapers',
#  'berries',
#  'soda',
#  'curd',
#  'flour',
#  'liquor (appetizer)',
#  'tropical fruit',
#  'other vegetables',
#  'coffee',
#  'soda',
#  'rolls/buns',
#  'Instant food products',
#  'canned beer',
#  'canned beer',
#  'frankfurter',
#  'sausage',
#  'whole milk',
#  'rolls/buns',
#  'margarine',
#  'other vegetables',
#  'misc. beverages',
#  'canned beer',
#  'whole milk',
#  'frozen vegetables',
#  'whole milk',
#  'citrus fruit',
#  'butter',
#  'cream cheese',
#  'white bread',
#  'oil',
#  'margarine',
#  'newspapers',
#  'frankfurter',
#  'rolls/buns',
#  'frankfurter',
#  'ham',
#  'pip fruit',
#  'other vegetables',
#  'whole milk',
#  'soft cheese',
#  'frozen vegetables',
#  'rolls/buns',
#  'sugar',
#  'baking powder',
#  'butter milk',
#  'yogurt',
#  'honey',
#  'soda',
#  'detergent',
#  'hamburger meat',
#  'citrus fruit',
#  'onions',
#  'rolls/buns',
#  'bottled water',
#  'dental care',
#  'pasta',
#  'popcorn',
#  'other vegetables',
#  'whole milk',
#  'meat spreads',
#  'cake bar',
#  'chocolate',
#  'shopping bags',
#  'sausage',
#  'pork',
#  'citrus fruit',
#  'dessert',
#  'white bread',
#  'dishes',
#  'candles',
#  'rolls/buns',
#  'grapes',
#  'other vegetables',
#  'curd',
#  'dessert',
#  'yogurt',
#  'napkins',
#  'root vegetables',
#  'other vegetables',
#  'whole milk',
#  'yogurt',
#  'beverages',
#  'soft cheese',
#  'frozen vegetables',
#  'fruit/vegetable juice',
#  'bottled beer',
#  'coffee',
#  'shopping bags',
#  'popcorn',
#  'whole milk',
#  'rolls/buns',
#  'sugar',
#  'bottled water',
#  'soda',
#  'tropical fruit',
#  'other vegetables',
#  'packaged fruit/vegetables',
#  'whole milk',
#  'snack products',
#  'beef',
#  'herbs',
#  'flour',
#  'cling film/bags',
#  'flower soil/fertilizer',
#  'whole milk',
#  'butter',
#  'dessert',
#  'rolls/buns',
#  'frankfurter',
#  'soda',
#  'chewing gum',
#  'tropical fruit',
#  'specialty cheese',
#  'bottled water',
#  'canned beer',
#  'finished products',
#  'other vegetables',
#  'frozen vegetables',
#  'bottled beer',
#  'beverages',
#  'soda',
#  'hamburger meat',
#  'root vegetables',
#  'whole milk',
#  'whole milk',
#  'pastry',
#  'long life bakery product',
#  'finished products',
#  'white wine',
#  'shopping bags',
#  'other vegetables',
#  'ham',
#  'tropical fruit',
#  'other vegetables',
#  'whole milk',
#  'white bread',
#  'brown bread',
#  'fruit/vegetable juice',
#  'bottled beer',
#  'other vegetables',
#  'curd',
#  'butter milk',
#  'cocoa drinks',
#  'salty snack',
#  'popcorn',
#  'bottled beer',
#  'curd',
#  'dessert',
#  'soda',
#  'salty snack',
#  'waffles',
#  'cake bar',
#  'chocolate',
#  'shopping bags',
#  'whole milk',
#  'cream cheese',
#  'cereals',
#  'dog food',
#  'whole milk',
#  'salt',
#  'dessert',
#  'ice cream',
#  'sausage',
#  'soft cheese',
#  'coffee',
#  'other vegetables',
#  'bottled water',
#  'waffles',
#  'dishes',
#  'shopping bags',
#  'ham',
#  'whole milk',
#  'rolls/buns',
#  'other vegetables',
#  'ice cream',
#  'other vegetables',
#  'bottled water',
#  'soda',
#  'bottled beer',
#  'white wine',
#  'prosecco',
#  'herbs',
#  'candy',
#  'frankfurter',
#  'ham',
#  'tropical fruit',
#  'pip fruit',
#  'root vegetables',
#  'other vegetables',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'whipped/sour cream',
#  'soft cheese',
#  'rolls/buns',
#  'canned beer',
#  'curd',
#  'cream cheese',
#  'semi-finished bread',
#  'zwieback',
#  'cake bar',
#  'specialty bar',
#  'shopping bags',
#  'frankfurter',
#  'tropical fruit',
#  'whole milk',
#  'spread cheese',
#  'margarine',
#  'shopping bags',
#  'other vegetables',
#  'dog food',
#  'specialty bar',
#  'curd',
#  'salt',
#  'liquor (appetizer)',
#  'detergent',
#  'shopping bags',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'beef',
#  'berries',
#  'root vegetables',
#  'whole milk',
#  'dessert',
#  'spread cheese',
#  'brown bread',
#  'canned beer',
#  'pork',
#  'beef',
#  'pip fruit',
#  'herbs',
#  'spices',
#  'frankfurter',
#  'citrus fruit',
#  'UHT-milk',
#  'margarine',
#  'sugar',
#  'sausage',
#  'bottled beer',
#  'liquor (appetizer)',
#  'canned beer',
#  'specialty chocolate',
#  'curd',
#  'rolls/buns',
#  'canned beer',
#  'whole milk',
#  'bottled water',
#  'newspapers',
#  'rolls/buns',
#  'chewing gum',
#  'pork',
#  'root vegetables',
#  'other vegetables',
#  'whole milk',
#  'dishes',
#  'citrus fruit',
#  'pastry',
#  'potted plants',
#  'rolls/buns',
#  'pastry',
#  'soda',
#  'butter',
#  'yogurt',
#  'bottled water',
#  'soda',
#  'make up remover',
#  'hygiene articles',
#  'condensed milk',
#  'sugar',
#  'coffee',
#  'shopping bags',
#  'sausage',
#  'other vegetables',
#  'yogurt',
#  'soda',
#  'shopping bags',
#  'whole milk',
#  'beverages',
#  'UHT-milk',
#  'soda',
#  'sausage',
#  'pork',
#  'beef',
#  'whole milk',
#  'rolls/buns',
#  'margarine',
#  'beverages',
#  'beverages',
#  'specialty bar',
#  'bottled water',
#  'fruit/vegetable juice',
#  'newspapers',
#  'cleaner',
#  'female sanitary products',
#  'sausage',
#  'soda',
#  'newspapers',
#  'shopping bags',
#  'newspapers',
#  'sausage',
#  'beef',
#  'citrus fruit',
#  'other vegetables',
#  'whole milk',
#  'butter milk',
#  'whipped/sour cream',
#  'beverages',
#  'hard cheese',
#  'rolls/buns',
#  'dish cleaner',
#  'cookware',
#  'misc. beverages',
#  'newspapers',
#  'white wine',
#  'sausage',
#  'sliced cheese',
#  'rolls/buns',
#  'soda',
#  'canned beer',
#  'shopping bags',
#  'meat',
#  'curd',
#  'bottled beer',
#  'cake bar',
#  'frankfurter',
#  'meat',
#  'tropical fruit',
#  'onions',
#  'oil',
#  'baking powder',
#  'tea',
#  'cling film/bags',
#  'ice cream',
#  'rolls/buns',
#  'canned beer',
#  'canned beer',
#  'tropical fruit',
#  'berries',
#  'root vegetables',
#  'other vegetables',
#  'bottled water',
#  'shopping bags',
#  'meat',
#  'citrus fruit',
#  'other vegetables',
#  'curd',
#  'dessert',
#  'butter milk',
#  'beverages',
#  'cream cheese',
#  'rolls/buns',
#  'brown bread',
#  'tea',
#  'bottled water',
#  'whole milk',
#  'mustard',
#  'bottled water',
#  'sausage',
#  'beef',
#  'beverages',
#  'sliced cheese',
#  'rolls/buns',
#  'spices',
#  'house keeping products',
#  'flower (seeds)',
#  'frankfurter',
#  'sausage',
#  'root vegetables',
#  'butter',
#  'curd',
#  'sliced cheese',
#  'rolls/buns',
#  'salty snack',
#  'long life bakery product',
#  'meat',
#  'other vegetables',
#  'butter',
#  'rolls/buns',
#  'root vegetables',
#  'beverages',
#  'Instant food products',
#  'pickled vegetables',
#  'detergent',
#  'root vegetables',
#  'herbs',
#  'other vegetables',
#  'whole milk',
#  'sliced cheese',
#  'rolls/buns',
#  'whole milk',
#  'whipped/sour cream',
#  'semi-finished bread',
#  'margarine',
#  'citrus fruit',
#  'whole milk',
#  'curd',
#  'dessert',
#  'yogurt',
#  'whipped/sour cream',
#  'frozen dessert',
#  'rolls/buns',
#  'salt',
#  'sugar',
#  'cereals',
#  'canned vegetables',
#  'citrus fruit',
#  'curd',
#  'pastry',
#  'margarine',
#  'sugar',
#  'candy',
#  'newspapers',
#  'other vegetables',
#  'whole milk',
#  'bottled water',
#  'soda',
#  'misc. beverages',
#  'bottled beer',
#  'red/blush wine',
#  'napkins',
#  'citrus fruit',
#  'whole milk',
#  'rolls/buns',
#  'sausage',
#  'oil',
#  'hygiene articles',
#  'napkins',
#  'frankfurter',
#  'beef',
#  'hamburger meat',
#  'grapes',
#  'root vegetables',
#  'whole milk',
#  'butter',
#  'frozen dessert',
#  'potato products',
#  'bottled water',
#  'bottled beer',
#  'hard cheese',
#  'rolls/buns',
#  'bottled water',
#  'newspapers',
#  'cream cheese',
#  'rolls/buns',
#  'soda',
#  'chocolate',
#  'turkey',
#  'beef',
#  'frozen vegetables',
#  'dishes',
#  'photo/film',
#  'pork',
#  'other vegetables',
#  'whipped/sour cream',
#  'rolls/buns',
#  'soda',
#  'shopping bags',
#  'whole milk',
#  'beverages',
#  'rolls/buns',
#  'soda',
#  'sausage',
#  'pip fruit',
#  'whole milk',
#  'curd',
#  'yogurt',
#  'sliced cheese',
#  'rolls/buns',
#  'bottled water',
#  'hygiene articles',
#  'ice cream',
#  'liquor',
#  'pip fruit',
#  'other vegetables',
#  'fruit/vegetable juice',
#  'root vegetables',
#  'other vegetables',
#  'yogurt',
#  'soda',
#  'soda',
#  'sausage',
#  'citrus fruit',
#  'tropical fruit',
#  'other vegetables',
#  'whole milk',
#  ...]

# %%
import collections

# %%
p = collections.Counter(l)

# %%
p.values()
# Out:
# dict_values([814, 165, 559, 16, 1032, 1369, 551, 2513, 744, 386, 40, 1903, 101, 328, 545, 66, 26, 1797, 329, 761, 75, 153, 52, 404, 1057, 433, 523, 166, 165, 516, 580, 1664, 422, 320, 647, 734, 128, 247, 275, 864, 163, 163, 1072, 105, 87, 341, 343, 258, 23, 752, 924, 628, 895, 255, 327, 49, 279, 443, 567, 327, 703, 30, 220, 365, 67, 613, 109, 267, 239, 221, 256, 80, 163, 168, 261, 198, 74, 245, 466, 133, 124, 50, 182, 79, 32, 271, 79, 95, 54, 102, 270, 98, 305, 160, 184, 41, 88, 236, 141, 48, 100, 29, 43, 30, 75, 166, 14, 49, 63, 118, 28, 18, 83, 64, 20, 80, 19, 8, 42, 50, 87, 23, 254, 35, 108, 64, 28, 108, 90, 62, 42, 110, 8, 52, 62, 24, 11, 70, 97, 89, 7, 28, 50, 14, 28, 48, 6, 35, 29, 40, 48, 12, 33, 9, 22, 13, 7, 16, 22, 23, 4, 8, 12, 4, 20, 1, 2, 2])

# %%
d = {"Item Name":p.keys(),"values":p.values()}

# %%
# pd.DataFrame(d).sort_values(by=["values"],ascending=False)

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder
tr = TransactionEncoder()
tr.fit(market)
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)
df
# Out:
#       Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                     False     False             False             False
# 1                     False     False             False             False
# 2                     False     False             False             False
# 3                     False     False             False             False
# 4                     False     False             False             False
# ...                     ...       ...               ...               ...
# 9830                  False     False             False             False
# 9831                  False     False             False             False
# 9832                  False     False             False             False
# 9833                  False     False             False             False
# 9834                  False     False             False             False
#
#       baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0              False  False          False             False  False    False
# 1              False  False          False             False  False    False
# 2              False  False          False             False  False    False
# 3              False  False          False             False  False    False
# 4              False  False          False             False  False    False
# ...              ...    ...            ...               ...    ...      ...
# 9830           False  False          False             False   True    False
# 9831           False  False          False             False  False    False
# 9832           False  False          False             False  False    False
# 9833           False  False          False             False  False    False
# 9834           False  False          False             False  False    False
#
#       ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0     ...   False    False    False               False   False        False
# 1     ...   False    False    False               False   False        False
# 2     ...   False    False    False               False   False        False
# 3     ...   False    False    False               False   False        False
# 4     ...   False    False    False               False   False        False
# ...   ...     ...      ...      ...                 ...     ...          ...
# 9830  ...   False    False    False                True   False        False
# 9831  ...   False    False    False               False   False        False
# 9832  ...   False    False    False               False   False        False
# 9833  ...   False    False    False               False   False        False
# 9834  ...   False     True    False               False   False        False
#
#       white wine  whole milk  yogurt  zwieback
# 0          False       False   False     False
# 1          False       False    True     False
# 2          False        True   False     False
# 3          False       False    True     False
# 4          False        True   False     False
# ...          ...         ...     ...       ...
# 9830       False        True   False     False
# 9831       False       False   False     False
# 9832       False       False    True     False
# 9833       False       False   False     False
# 9834       False       False   False     False
#
# [9835 rows x 168 columns]

# %%
from mlxtend.frequent_patterns import apriori
apriori(df,min_support=0.05,use_colnames=True,max_len=3).sort_values(by=["support"])
# Out:
#      support                        itemsets
# 0   0.052466                          (beef)
# 8   0.053177                          (curd)
# 4   0.055414                        (butter)
# 28  0.055618        (whole milk, rolls/buns)
# 29  0.055719            (whole milk, yogurt)
# 7   0.056024                        (coffee)
# 12  0.056838                     (margarine)
# 17  0.057651                          (pork)
# 10  0.058973                   (frankfurter)
# 9   0.062328                 (domestic eggs)
# 3   0.063854                   (brown bread)
# 11  0.065785         (fruit/vegetable juice)
# 24  0.071479            (whipped/sour cream)
# 13  0.074631                    (newspapers)
# 27  0.074835  (whole milk, other vegetables)
# 16  0.075648                     (pip fruit)
# 5   0.076462                   (canned beer)
# 1   0.077377                  (bottled beer)
# 6   0.082766                  (citrus fruit)
# 15  0.087850                        (pastry)
# 21  0.091002                 (shopping bags)
# 20  0.093950                       (sausage)
# 23  0.104931                (tropical fruit)
# 2   0.107473                 (bottled water)
# 19  0.108998               (root vegetables)
# 26  0.139197                        (yogurt)
# 22  0.169192                          (soda)
# 18  0.182715                    (rolls/buns)
# 14  0.193493              (other vegetables)
# 25  0.255516                    (whole milk)

# %%
dataset["Item 1"][9834]
# Out:
# 'chicken'
